# %%
'''
    Music-Hits
    An analysis of Billboard 100 Charts
    Project By Williambd
    
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()

# %%
df = pd.read_csv("C:\\Users\\LiamDeaton\\Documents\\DATAProj\\Billboard-Data\\Hits-Analysis\\kcmillersean-billboard-hot-100-1958-2017\\kcmillersean-billboard-hot-100-1958-2017\\Hot Stuff.csv")
#features = pd.read_excel("C:\\Users\\LiamDeaton\\Documents\\DATAProj\\Billboard-Data\\Hits-Analysis\\kcmillersean-billboard-hot-100-1958-2017\\kcmillersean-billboard-hot-100-1958-2017\\Hot 100 Audio Features.xlsx")

# %%
df.sample(5)
# Out:
#                                                       url      WeekID  \
# 292316  http://www.billboard.com/charts/hot-100/1980-0...   3/22/1980
# 247654  http://www.billboard.com/charts/hot-100/1995-0...    9/2/1995
# 17240   http://www.billboard.com/charts/hot-100/1993-0...   8/21/1993
# 226044  http://www.billboard.com/charts/hot-100/1989-1...  12/23/1989
# 182950  http://www.billboard.com/charts/hot-100/1967-0...    9/2/1967
#
#         Week Position                                   Song  \
# 292316             26                              Sexy Eyes
# 247654             10                 Only Wanna Be With You
# 17240              80      Big Gun (From "Last Action Hero")
# 226044             21                              Oh Father
# 182950             68  Laura, What's He Got That I Ain't Got
#
#                     Performer  \
# 292316               Dr. Hook
# 247654  Hootie & The Blowfish
# 17240                   AC/DC
# 226044                Madonna
# 182950          Frankie Laine
#
#                                                    SongID  Instance  \
# 292316                                  Sexy EyesDr. Hook         1
# 247654        Only Wanna Be With YouHootie & The Blowfish         1
# 17240              Big Gun (From "Last Action Hero")AC/DC         1
# 226044                                   Oh FatherMadonna         1
# 182950  Laura, What's He Got That I Ain't GotFrankie L...         1
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 292316                    31.0             26               6
# 247654                    12.0             10               5
# 17240                     75.0             65               8
# 226044                    27.0             21               7
# 182950                    74.0             68               4

# %%
#df[df["SongID"]=="DreamsFleetwood Mac"]

# %%
#df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320495 entries, 0 to 320494
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   url                     320495 non-null  object
#  1   WeekID                  320495 non-null  object
#  2   Week Position           320495 non-null  int64
#  3   Song                    320495 non-null  object
#  4   Performer               320495 non-null  object
#  5   SongID                  320495 non-null  object
#  6   Instance                320495 non-null  int64
#  7   Previous Week Position  289711 non-null  float64
#  8   Peak Position           320495 non-null  int64
#  9   Weeks on Chart          320495 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 24.5+ MB

# %%
df['WeekID'] = pd.to_datetime(df.WeekID) #transfers WeekID to ISO Date Format

# %%
df[df['Song']=='Goosebumps'].sort_values('WeekID').sample(4) #sorts to placemet
# Out:
#                                                       url     WeekID  \
# 314335  http://www.billboard.com/charts/hot-100/2016-1... 2016-10-15
# 320434  http://www.billboard.com/charts/hot-100/2017-0... 2017-03-11
# 320485  http://www.billboard.com/charts/hot-100/2017-0... 2017-07-22
# 320474  http://www.billboard.com/charts/hot-100/2017-0... 2017-05-06
#
#         Week Position        Song     Performer                  SongID  \
# 314335             91  Goosebumps  Travis Scott  GoosebumpsTravis Scott
# 320434             62  Goosebumps  Travis Scott  GoosebumpsTravis Scott
# 320485             47  Goosebumps  Travis Scott  GoosebumpsTravis Scott
# 320474             46  Goosebumps  Travis Scott  GoosebumpsTravis Scott
#
#         Instance  Previous Week Position  Peak Position  Weeks on Chart
# 314335         2                    97.0             91               3
# 320434         5                    61.0             51              16
# 320485         6                    42.0             32              34
# 320474         6                    43.0             43              23

# %%
#Figuring out how to specify data from a particular artist
trav = df.loc[df['Performer']=='Travis Scott'].sort_values(['WeekID'],ascending=False).reset_index(drop=True)

# %%
trav.head()
# Out:
#                                                  url     WeekID  \
# 0  https://www.billboard.com/charts/hot-100/2019-... 2019-12-28
# 1  https://www.billboard.com/charts/hot-100/2019-... 2019-12-21
# 2  https://www.billboard.com/charts/hot-100/2019-... 2019-12-14
# 3  https://www.billboard.com/charts/hot-100/2019-... 2019-12-07
# 4  https://www.billboard.com/charts/hot-100/2019-... 2019-11-30
#
#    Week Position                 Song     Performer  \
# 0             27  HIGHEST IN THE ROOM  Travis Scott
# 1             25  HIGHEST IN THE ROOM  Travis Scott
# 2             20  HIGHEST IN THE ROOM  Travis Scott
# 3             15  HIGHEST IN THE ROOM  Travis Scott
# 4             14  HIGHEST IN THE ROOM  Travis Scott
#
#                             SongID  Instance  Previous Week Position  \
# 0  HIGHEST IN THE ROOMTravis Scott         1                    25.0
# 1  HIGHEST IN THE ROOMTravis Scott         1                    20.0
# 2  HIGHEST IN THE ROOMTravis Scott         1                    15.0
# 3  HIGHEST IN THE ROOMTravis Scott         1                    14.0
# 4  HIGHEST IN THE ROOMTravis Scott         1                    12.0
#
#    Peak Position  Weeks on Chart
# 0              1              11
# 1              1              10
# 2              1               9
# 3              1               8
# 4              1               7

# %%
#make a plot
plt.gca().invert_yaxis()
plt.xticks(rotation=90)
plt.plot(trav['WeekID'], trav['Week Position'], 'o', color='black')

# %%
groups = trav.groupby("Song")

for name, group in groups:

    plt.plot(group["WeekID"], group["Song"], marker="o", linestyle="", label=name)
    plt.xticks(rotation=90)

plt.title("Travis Scott Song Chart")
#plt.legend()
# Out:
# Text(0.5, 1.0, 'Travis Scott Song Chart')

# %%
trav = trav.sort_values("WeekID")
groups = trav.groupby("Song",sort = False)

for name, group in groups:

    plt.plot(group["WeekID"], group["Week Position"], marker="o", markersize=5, linestyle="",label=name)
plt.gca().invert_yaxis()
plt.xticks(rotation=90)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [raw]
# def artist_history(artist):
#     """Creates a chart of an artists billboard hits,
#     Showing which songs were on the charts over time"""
#     sns.set()
#     #data frame isolated for given artists music, sorted by date
#     artist_stats = df.loc[df['Performer']==artist].sort_values(['WeekID']).reset_index(drop=True)
#
#     groups = artist_stats.groupby(["Song"], sort=False) #Groups Songs into
#
#     fig = plt.figure(figsize = (10,0.25*len(groups))) #figure is longer if artist has more songs
#
#     ax = sns.scatterplot(data=artist_stats,x='WeekID',y='Song', hue='SongID', legend = False)
#     plt.xticks(rotation=-75) #plot dat buoy
#
#     #plot for each song
#     #for name, group in groups:
#      #   ax.plot(group["WeekID"], group["Song"], marker="o", linestyle="", label=name)
#
#
#     fig.autofmt_xdate() #date format
#     ax.invert_yaxis() #earlier songs at the top
#     ax.set(xlabel = 'Week', ylabel='Song', title = artist+' Chart History', xlim=(artist_stats.WeekID.min(),artist_stats.WeekID.max()) ) #chart n stuff

# %%
def artist_history(artist, search_by_string = False):
    """Creates a chart of an artists billboard hits, 
    Showing which songs were on the charts over time"""
    
    #data frame isolated for given artists music, sorted by date
    sns.set()
    sns.set_palette("husl",8)
    if search_by_string:
        artist_stats = df.loc[df['Performer'].str.contains(artist)].sort_values(['WeekID']).reset_index(drop=True)
    else:
        artist_stats = df.loc[df['Performer']==artist].sort_values(['WeekID']).reset_index(drop=True)
    
    groups = artist_stats.groupby(["Song"], sort=False) #Groups Songs into 
    
    fig = plt.figure(figsize = (10,0.25*len(groups))) #figure is longer if artist has more songs
    
    ax = sns.scatterplot(data=artist_stats,x='WeekID',y='Song', hue='SongID', linewidth = 0,legend = False, palette = "muted") #plot
    #ax = plt.axes()
    plt.xticks(rotation=-75) 
    
    #plot for each song
    #for name, group in groups:
    #    ax.plot(group["WeekID"], group["Song"], marker="o", linestyle="", label=name)
    
    
    fig.autofmt_xdate() #date format
    ax.invert_yaxis() #earlier songs at the top
    ax.set(xlabel = 'Week', ylabel='Song', title = artist+' Chart History', xlim=(artist_stats.WeekID.min(),artist_stats.WeekID.max()) ) #chart n stuff

# %%
def artist_position(artist,search_by_string = False):
    """Makes a Jackson Polluck Painting"""
    sns.set()
    #dataframe isolated for artist, sorted by date
    if search_by_string:
        artist_songs = df.loc[df['Performer'].str.contains(artist)].sort_values(['WeekID']).reset_index(drop=True)
    else:
        artist_songs = df.loc[df['Performer']==artist].sort_values(['WeekID']).reset_index(drop=True)
    
    groups = artist_songs.groupby(["Song"], sort=False) #each song in the group
    
    #plot
    fig = plt.figure()
    ax = sns.scatterplot(data=artist_songs,x='WeekID',y='Week Position', hue='Song', legend = False)
    plt.xticks(rotation=-75)
    
    #plot each song
    #for name, group in groups:
        #plots position on charts of each song over time
        #ax.plot(group["WeekID"], group["Week Position"], marker="o", linestyle="", label=name)
    
    plt.gca().invert_yaxis()
    ax.set(title = artist +" Song Chart", xlabel = "Week", ylabel = 'Billboard Position', xlim=(artist_songs.WeekID.min(),artist_songs.WeekID.max()))
#plt.legend()

# %% [raw]
# def artist_history(artist1, artist2):
#     stats1 = df.loc[df['Performer']==artist1].sort_values(['WeekID'], ascending=True).reset_index(drop=True)
#     stats1c = stats1.index.values
#     stats2 = df.loc[df['Performer']==artist2].sort_values(['WeekID'], ascending=True).reset_index(drop=True)
#     stats2c = stats2.index.values
#     height = (len(stats1['Song'].drop_duplicates())+len(stats2['Song'].drop_duplicates()))
#     plt.xticks(rotation=90)
#     fig = plt.figure(figsize = (5,.25*height)).gca().invert_yaxis()
#     ax1 = plt.axes()
#     ax2 = plt.axes()
# #     ax.plot(stats1['WeekID'],stats2['Song'],marker='o',c=marker_colors1,cmap='inferno')
#     marker_colors1 = [i/len(stats1c)*100 for i in stats1c]
#     ax1.scatter(stats1['WeekID'],stats1['Song'],marker='o',c=marker_colors1, cmap='inferno')
#     marker_colors2 = [i/len(stats2c)*100 for i in stats2c]
#     ax2.scatter(stats2['WeekID'],stats2['Song'],marker='o', c=marker_colors2, cmap='inferno')
# #     x= plt.scatter(stats1['WeekID'], stats1['Song'], marker='o',c=marker_colors1,cmap='inferno')
# #     y= plt.scatter(stats2['WeekID'], stats2['Song'], marker='bo', c=marker_colors2, cmap='inferno')

# %%
artist_history('The Beatles')
artist_position('Bruno Mars')

# %%
#Most Songs On Billboard
unique_songs = df.drop_duplicates(subset = ["SongID"])
unique_songs["Performer"].value_counts().head(20)
#Problem, songs featuring multiple artists not counted, ie. "artist Feat. foo" would not add to "artist" count
# Out:
# Glee Cast                             183
# Drake                                  90
# Taylor Swift                           84
# The Beatles                            65
# Aretha Franklin                        64
# Elton John                             58
# The Rolling Stones                     57
# Stevie Wonder                          54
# Connie Francis                         53
# The Beach Boys                         53
# Madonna                                53
# Elvis Presley With The Jordanaires     53
# Neil Diamond                           52
# Elvis Presley                          50
# The Temptations                        49
# Ray Charles                            48
# Brenda Lee                             48
# Jackie Wilson                          48
# James Brown                            47
# Rod Stewart                            47
# Name: Performer, dtype: int64

# %%
#Most number 1 hits
top_songs = df[df["Peak Position"]==1]
top_songs = top_songs.drop_duplicates(subset = ["SongID"])
top_songs["Performer"].value_counts().head(10)
#Problem: Songs Featuring multiple Artists not counted ie. "artist Feat. foo" or "artist and bar"
# Out:
# The Beatles           19
# Mariah Carey          16
# Madonna               12
# Michael Jackson       11
# Whitney Houston       11
# The Supremes          10
# Bee Gees               9
# The Rolling Stones     8
# Janet Jackson          7
# Stevie Wonder          7
# Name: Performer, dtype: int64

# %% [raw]
# ft_key_words = [' Ft. ',' Ft ', ' Featuring ', ' With ',' & ']
# all_performers = []
#
# for artist in df["Performer"]:
#     artists = artist
#     for word in ft_key_words:
#         artists.replace('!/ARTISTSPLIT', word)
#     artists.split('!/ARTISTSPLIT')
#     all_performers.append(artists)
# all_performers[1]

# %%
"""
#Differentiates between a featured artist and main artist
#I would like to be able to differentiate between, say "Elvis Presly And The Jordanaires" and separate Elvis Presly,
#but separating by "and" would split many bands such as "Earth, Wind And Fire" into seperate artists "Earth, Wind" and "Fire"
#You see the problem :) 
"""
ft_key_words = [' Ft. ',' Ft ', ' Featuring ', ' With ']
mb_key_words = [' and ']
all_performers = []

allartists = df.groupby["Performer"]

for artist,  in allartists:
    artists = str(artist)
    for word in ft_key_words:
        artists = artists.replace(word, '!/ARTISTSPLIT')
    for word in mb_key_words:
        if word in artists:
            rip = input(artists+" replace? y/n :>")
            if rip == "y":
                artists = artists.replace(word, '!/ARTISTSPLIT')
    artists = artists.split('!/ARTISTSPLIT')
    all_performers.append(artists)
df["all_performers"] = all_performers
# Out:
# Cathy Jean and The Roommates replace? y/n :>n
# Dante and the Evergreens replace? y/n :>n
# Eugene Church and The Fellows replace? y/n :>n
# Paul Evans and the Curls replace? y/n :>n
# Hudson and Landry replace? y/n :>n
# Joe South and The Believers replace? y/n :>n
# Lloyd Price and His Orchestra replace? y/n :>y
# Phil Collins and Marilyn Martin replace? y/n :>y
# Bent Fabric and His Piano replace? y/n :>n
# Duane Eddy and the Rebelettes replace? y/n :>n
# Martin Denny and His Orchestra replace? y/n :>y
# Donnie and The Dreamers replace? y/n :>n
# Sam The Sham and the Pharaohs replace? y/n :>y
# Ray Charles and his Orchestra replace? y/n :>y
# Dick and DeeDee replace? y/n :>n
# Jerry Butler and The Impressions replace? y/n :>y
# Raymond Lefevre and His Orchestra replace? y/n :>y
# Buck Owens and The Buckaroos replace? y/n :>y
# Tom and Jerrio replace? y/n :>n
# Johnny Beecher and his Buckingham Road Quintet replace? y/n :>y
# Ray Anthony and His Orchestra replace? y/n :>y
# Lee and Paul replace? y/n :>n
# Mitch Miller and his "Sing Along!/ARTISTSPLITMitch" Chorus replace? y/n :>y
# Jimmy Charles and The Revelletts replace? y/n :>y
# Paul Chaplain and his Emeralds replace? y/n :>y
# Barry DeVorzon and Perry Botkin, Jr. replace? y/n :>y
# Joe Cocker and The Chris Stainton Band replace? y/n :>y
# Oscar McLollie and Jeanette Baker replace? y/n :>y
# J. Frank Wilson and The Cavaliers replace? y/n :>n
# Elvis Presley!/ARTISTSPLITThe Jordanaires and The Imperials Quartet replace? y/n :>y
# Harlow Wilcox and the Oakies replace? y/n :>n
# Ronnie Hawkins and The Hawks replace? y/n :>y
# Edmundo Ros and His Orchestra replace? y/n :>y
# Kenny Ball and his Jazzmen replace? y/n :>y
# Mickey Shorr and The Cutups replace? y/n :>n
# Paul and Paula replace? y/n :>n
# Cliff Richard and The Drifters replace? y/n :>n
# Rocco Granata and the International Quintet replace? y/n :>y
# Edd Byrnes and Friend replace? y/n :>y
# Ivo Robic and The Song-Masters replace? y/n :>n
# Ronnie and The Hi-Lites replace? y/n :>n
# Little Bill and The Bluenotes replace? y/n :>n
# John Barry and His Orchestra replace? y/n :>y
# Sharon Paige and Harold Melvin And The Blue Notes replace? y/n :>y
# Little Caesar and The Romans replace? y/n :>n
# Bob Moore and His Orch. replace? y/n :>y
# Hayley Mills and Hayley Mills replace? y/n :>y
# Jon Thomas and Orchestra replace? y/n :>y
# Pat and the Satellites replace? y/n :>n
# Charlie Ryan and the Timberline Riders replace? y/n :>n
# Dick Dale and The Del-Tones replace? y/n :>n
# Dr. West's Medicine Show and Junk Band replace? y/n :>n
# Bobby Gregg and His Friends replace? y/n :>n
# Eddie and Betty replace? y/n :>n
# Bobby Vee and The Shadows replace? y/n :>n
# Steve Allen and His Orchestra with The Copacabana Trio replace? y/n :>y
# Mitch Miller and his Orchestra and Chorus replace? y/n :>y
# Dave York and The Beachcombers replace? y/n :>n
# Johnny and The Expressions replace? y/n :>n
# 5 Stairsteps and Cubie replace? y/n :>y
# Jim and Monica replace? y/n :>n
# Danny Peppermint and the Jumping Jacks replace? y/n :>

# %%
artist_history("Prince")

# %%
def top1_by_year(year):
    '''
    returns the top hits of given year
    '''
    top1 = df.loc[df['Week Position']==1].reset_index(drop=True)
    top1 = top1.drop(columns=['url']).sort_values('WeekID').reset_index(drop=True)
    top1['Year'] = pd.DatetimeIndex(top1['WeekID']).year
    top1_year = top1.loc[top1['Year']==year]
    return top1_year

# %%
def generic_cascade(songs, chart_title = 'Chart History', width = 10, display_artist=False):
    """Creates cascading chart in the style of ARTIST HISTORY,
        Given a dataframe of songs
    """
    
    #sorts songs by date
    songs = songs.sort_values(['WeekID']).reset_index(drop=True)
    
    groups = songs.groupby(["Song"], sort=False) #Groups by song 

    fig = plt.figure(figsize = (width,0.25*len(groups))) #figure is longer if artist has more songs
    
    ax = plt.axes() #plot dat boy
    
    #So that we can see the artist if our list containes many artists
    if display_artist:
        label = "SongID"
    else:
        label = "Song"
    
    #plot for each song
    for name, group in groups:
        ax.plot(group["WeekID"], group[label], marker="o", linestyle="", label=name)
    fig.autofmt_xdate() #date format
    ax.invert_yaxis() #earlier songs at the top
    ax.set(xlabel = 'Week', ylabel='Song', title = chart_title) #chart n stuff

# %%
songs_2001 = top1_by_year(2002)
generic_cascade(songs_2001,"2002 Top Charts Songs", width = 5)

# %%
def top1_period(start_year, end_year):
    
    top1 = df.loc[df['Week Position']==1].reset_index(drop=True)
    top1 = top1.drop(columns=['url']).sort_values('WeekID').reset_index(drop=True)
    top1['Year'] = pd.DatetimeIndex(top1['WeekID']).year
    
    top1_interval = top1.loc[(top1['Year']>=start_year) & (top1['Year']<(end_year))]

    return top1_interval

# %%
top1_by_year(2005).drop_duplicates("Song")
# Out:
#          WeekID  Week Position                   Song  \
# 2422 2005-01-01              1        Let Me Love You
# 2431 2005-03-05              1             Candy Shop
# 2440 2005-05-07              1         Hollaback Girl
# 2444 2005-06-04              1     We Belong Together
# 2448 2005-07-02              1     Inside Your Heaven
# 2459 2005-09-17              1            Gold Digger
# 2469 2005-11-26              1                Run It!
# 2474 2005-12-31              1  Don't Forget About Us
#
#                             Performer  \
# 2422                            Mario
# 2431         50 Cent Featuring Olivia
# 2440                     Gwen Stefani
# 2444                     Mariah Carey
# 2448                 Carrie Underwood
# 2459  Kanye West Featuring Jamie Foxx
# 2469                      Chris Brown
# 2474                     Mariah Carey
#
#                                           SongID  Instance  \
# 2422                        Let Me Love YouMario         1
# 2431          Candy Shop50 Cent Featuring Olivia         1
# 2440                  Hollaback GirlGwen Stefani         1
# 2444              We Belong TogetherMariah Carey         1
# 2448          Inside Your HeavenCarrie Underwood         1
# 2459  Gold DiggerKanye West Featuring Jamie Foxx         1
# 2469                          Run It!Chris Brown         1
# 2474           Don't Forget About UsMariah Carey         1
#
#       Previous Week Position  Peak Position  Weeks on Chart  \
# 2422                     2.0              1              11
# 2431                     2.0              1               5
# 2440                     3.0              1               6
# 2444                     2.0              1               8
# 2448                     NaN              1               1
# 2459                    19.0              1               8
# 2469                     2.0              1              14
# 2474                     2.0              1              11
#
#                 all_performers  Year
# 2422                   [Mario]  2005
# 2431         [50 Cent, Olivia]  2005
# 2440            [Gwen Stefani]  2005
# 2444            [Mariah Carey]  2005
# 2448        [Carrie Underwood]  2005
# 2459  [Kanye West, Jamie Foxx]  2005
# 2469             [Chris Brown]  2005
# 2474            [Mariah Carey]  2005

# %%
df[df["Performer"]=="Glee Cast"].drop_duplicates("Song").sort_values("WeekID").head(10)
# Out:
#                                                       url     WeekID  \
# 37      http://www.billboard.com/charts/hot-100/2009-0... 2009-06-06
# 102985  http://www.billboard.com/charts/hot-100/2009-0... 2009-06-06
# 3109    http://www.billboard.com/charts/hot-100/2009-0... 2009-09-26
# 9280    http://www.billboard.com/charts/hot-100/2009-1... 2009-10-10
# 51508   http://www.billboard.com/charts/hot-100/2009-1... 2009-10-10
# 13591   http://www.billboard.com/charts/hot-100/2009-1... 2009-10-24
# 13754   http://www.billboard.com/charts/hot-100/2009-1... 2009-10-24
# 14298   http://www.billboard.com/charts/hot-100/2009-1... 2009-10-31
# 27958   http://www.billboard.com/charts/hot-100/2009-1... 2009-10-31
# 1076    http://www.billboard.com/charts/hot-100/2009-1... 2009-11-07
#
#         Week Position                                Song  Performer  \
# 37                  4                Don't Stop Believin'  Glee Cast
# 102985             98                               Rehab  Glee Cast
# 3109               46                          Take A Bow  Glee Cast
# 9280               71                      Taking Chances  Glee Cast
# 51508              85                    Somebody To Love  Glee Cast
# 13591              30  It's My Life / Confessions Part II  Glee Cast
# 13754              40          Halo / Walking On Sunshine  Glee Cast
# 14298              56                     Keep Holding On  Glee Cast
# 27958              65                              No Air  Glee Cast
# 1076               34                      Sweet Caroline  Glee Cast
#
#                                              SongID  Instance  \
# 37                    Don't Stop Believin'Glee Cast         1
# 102985                               RehabGlee Cast         1
# 3109                            Take A BowGlee Cast         1
# 9280                        Taking ChancesGlee Cast         1
# 51508                     Somebody To LoveGlee Cast         1
# 13591   It's My Life / Confessions Part IIGlee Cast         1
# 13754           Halo / Walking On SunshineGlee Cast         1
# 14298                      Keep Holding OnGlee Cast         1
# 27958                               No AirGlee Cast         1
# 1076                        Sweet CarolineGlee Cast         1
#
#         Previous Week Position  Peak Position  Weeks on Chart all_performers
# 37                         NaN              4               1    [Glee Cast]
# 102985                     NaN             98               1    [Glee Cast]
# 3109                       NaN             46               1    [Glee Cast]
# 9280                       NaN             71               1    [Glee Cast]
# 51508                      NaN             85               1    [Glee Cast]
# 13591                      NaN             30               1    [Glee Cast]
# 13754                      NaN             40               1    [Glee Cast]
# 14298                      NaN             56               1    [Glee Cast]
# 27958                      NaN             65               1    [Glee Cast]
# 1076                       NaN             34               1    [Glee Cast]

# %%
artist_history("The Black Eyed Peas")

# %%
#movie revivals
artist_history("The Beatles")
artist_history("Queen")

#dead revivals
artist_history("David Bowie")
artist_history("Prince")

artist_history("Ray Parker Jr.")

#artists
artist_history("Marvin Gaye")

# %%
#Test For Revivals
from datetime import timedelta
timeline = df.sort_values(["WeekID"])
all_songs = timeline.groupby(["SongID"],sort=False)

revival_songs = []
for name, song in all_songs:
    
    #Explanation of this.. So any WeekID that is more than a year from initial week ID will in the dataframe. Then we check if em
    if not song[song["WeekID"] >= song["WeekID"].iloc[0] + timedelta(days = 365*5)].empty :
        revival_songs.append(name)
        print(name)
# Out:
# Run Rudolph RunChuck Berry
# Jingle Bell RockBobby Helms
# White ChristmasBing Crosby
# VenusFrankie Avalon
# I Can't Get You Out Of My HeartAl Martino
# Tall Cool OneThe Wailers
# Harlem NocturneThe Viscounts
# Come Rain Or Come ShineRay Charles
# Rockin' Around The Christmas TreeBrenda Lee
# The Christmas Song (Merry Christmas To You)Nat King Cole
# Stand By MeBen E. King
# Breaking Up Is Hard To DoNeil Sedaka
# Do You Love MeThe Contours
# Monster MashBobby "Boris" Pickett And The Crypt-Kickers
# Surfin' U.S.A.The Beach Boys
# Twist And ShoutThe Beatles
# Help The PoorB.B. King
# Last KissJ. Frank Wilson and The Cavaliers
# Unchained MelodyThe Righteous Brothers
# They're Coming To Take Me Away, Ha-Haaa!Napoleon XIV
# Ode To Billie JoeBobbie Gentry
# Daydream BelieverThe Monkees
# Guitar ManElvis Presley
# Living In The U.s.a.The Steve Miller Band
# 25 Or 6 To 4Chicago
# LolaThe Kinks
# I Just Want To Make Love To YouFoghat
# Space OddityDavid Bowie
# Bohemian RhapsodyQueen
# Solsbury HillPeter Gabriel
# We Will Rock You/We Are The ChampionsQueen
# LightsJourney
# Into The NightBenny Mardones
# Fool For Your LovingWhitesnake
# Under PressureQueen & David Bowie
# Hot In The CityBilly Idol
# What About MeMoving Pictures
# 1999Prince
# ValerieSteve Winwood
# Billie JeanMichael Jackson
# Little Red CorvettePrince
# I Melt With YouModern English
# When I'm With YouSheriff
# Red Red WineUB40
# ThrillerMichael Jackson
# When Doves CryPrince
# Let's Go CrazyPrince And The Revolution
# Purple RainPrince And The Revolution
# I Would Die 4 UPrince And The Revolution
# Careless WhisperWham! Featuring George Michael
# Raspberry BeretPrince And The Revolution
# Tarzan Boy (From "Teenage Mutant Ninja Turtles III")Baltimora
# Home Sweet HomeMotley Crue
# How Will I KnowWhitney Houston
# KissPrince And The Revolution
# Greatest Love Of AllWhitney Houston
# Livin' On A PrayerBon Jovi
# I Wanna Dance With Somebody (Who Loves Me)Whitney Houston
# FaithGeorge Michael
# The Star Spangled BannerWhitney Houston
# I Will Always Love YouWhitney Houston
# My BooGhost Town DJ's
# All I Want For Christmas Is YouMariah Carey
# Get Ur Freak OnMissy "Misdemeanor" Elliott
# Only TimeEnya
# In The EndLinkin Park
# Work ItMissy "Misdemeanor" Elliott
# NumbLinkin Park
# Get Me BodiedBeyonce
# Bad RomanceLady Gaga
# Underneath The TreeKelly Clarkson

# %%
sns.set()
generic_cascade(df[df["SongID"].isin(revival_songs)],chart_title = "Comeback Songs", display_artist = True)

# %% [markdown]
# SONGS I'M Curious about ON THIS LIST
# Venus = Frankie Avalon
# I Can't get you out of my head
# come rain or come shine
# THE CHRISTMAS SONG
# Rockin around the Christmas tree
# Stand by me
# David Seville and the chipmunks
#
# do u love me the contours --> Revival due to 1987's Dirty Dancing
#
# surfin usa
# twist and shout
# unchained melody
# lights journey
# we are the champions
# under pressure
#
# 1999 prince --> revives in 1999 XD
#
# billie jean
#
# thriller --> streaming effect
#
# how will IK witney --> 2012 Death led to revival of many of Witney Houstons Greatest Songs
#
# star spangled Banner Witney ---> ORIGINALLY RELEASED DURING THE SUPER BOWL OF 1991 (10 days into gulf war), RERELEASE AFTER 9/11, after which it peaked at #6 on hot charts
#
# livin on a prayer -->2013 when this 2009 vid goes viral https://www.youtube.com/watch?v=mOHkRk00iI8
#
# my boo --> 2016 VIRAL RUNNING MAN CHALLENGE
# all i want 4 christmas
#
# bad romance  --> PROBABLY REVIVED DUE TO 2017 HALFTIME PERFORMANCE (WHICH IS KILLER BTW, GO WATCH IT)
#
# 25 or 6 to 4 --> Re released in 1986

# %%
artist_history("The Everly Brothers")

# %%
df[df["Song"]=="Finesse"].head()
# Out:
#                                                       url     WeekID  \
# 13659   https://www.billboard.com/charts/hot-100/2018-... 2018-01-13
# 13802   https://www.billboard.com/charts/hot-100/2018-... 2018-07-14
# 84431   https://www.billboard.com/charts/hot-100/2018-... 2018-01-20
# 90163   https://www.billboard.com/charts/hot-100/2018-... 2018-07-21
# 114884  https://www.billboard.com/charts/hot-100/2018-... 2018-02-10
#
#         Week Position     Song             Performer  \
# 13659              35  Finesse  Bruno Mars & Cardi B
# 13802              42  Finesse                 Drake
# 84431               3  Finesse  Bruno Mars & Cardi B
# 90163              78  Finesse                 Drake
# 114884              3  Finesse  Bruno Mars & Cardi B
#
#                              SongID  Instance  Previous Week Position  \
# 13659   FinesseBruno Mars & Cardi B         1                     NaN
# 13802                  FinesseDrake         1                     NaN
# 84431   FinesseBruno Mars & Cardi B         1                    35.0
# 90163                  FinesseDrake         1                    42.0
# 114884  FinesseBruno Mars & Cardi B         1                     5.0
#
#         Peak Position  Weeks on Chart          all_performers
# 13659              35               1  [Bruno Mars & Cardi B]
# 13802              42               1                 [Drake]
# 84431               3               2  [Bruno Mars & Cardi B]
# 90163              42               2                 [Drake]
# 114884              3               5  [Bruno Mars & Cardi B]

# %%
df[df["Performer"== "Bruno Mars & Cardi B"]].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-c9c19d9d9085> in <module>
# ----> 1 df[df["Performer"== "Bruno Mars & Cardi B"]].head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False

# %%
# Out:
# hihello
